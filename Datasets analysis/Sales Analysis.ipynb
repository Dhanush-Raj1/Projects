# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"F:\datasets\sales_data.csv")

# %%
data.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
data['Customer_Age'].mean()
# Out:
# 35.91921157861212

# %%
data['Customer_Age'].plot(kind='kde', fig=(20,4))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data['Customer_Age'].plot(kind = 'box', vert=False, figsize=(8,4))
# Out:
# <AxesSubplot:>

# %%
data['Order_Quantity'].mean()
# Out:
# 11.901659648253654

# %%
data['Order_Quantity'].plot(kind='hist', bins=20, figsize=(10,4))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.distplot(data['Order_Quantity'], bins=20, hist=True, kde=True, vertical=False)
# Out:
# <AxesSubplot:xlabel='Order_Quantity', ylabel='Density'>

# %%
data['Order_Quantity'].plot(kind='kde', figsize=(12,5))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
data['Year'].value_counts()
# Out:
# 2014    29398
# 2016    29398
# 2013    24443
# 2015    24443
# 2012     2677
# 2011     2677
# Name: Year, dtype: int64

# %%
data['Year'].value_counts().plot(kind='pie', legend=True, title="sales in each year", figsize=(20,4))
# Out:
# <AxesSubplot:title={'center':'sales in each year'}, ylabel='Year'>

# %%
data['Month'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:>

# %%
data['Country'].value_counts().plot(kind='bar', figsize=(20,4))
# Out:
# <AxesSubplot:>

# %%
data['Product_Category'].value_counts()
# Out:
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: Product_Category, dtype: int64

# %%
data['Product_Category'].unique()
# Out:
# array(['Accessories', 'Clothing', 'Bikes'], dtype=object)

# %%
data['Product'].value_counts().head(10).plot(kind='bar', figsize=(20,6))
# Out:
# <AxesSubplot:>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
data.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(16,4))
# Out:
# <AxesSubplot:xlabel='Unit_Cost', ylabel='Unit_Price'>

# %%
data.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
data.plot(kind='scatter', x='Order_Quantity', y='Profit', figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Order_Quantity', ylabel='Profit'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
data[['Profit', 'Country']].boxplot(by='Country', figsize=(16,6))
# Out:
# <AxesSubplot:title={'center':'Profit'}, xlabel='[Country]'>

# %%
sns.barplot(data['Country'], data['Profit'])
# Out:
# C:\Users\Gokul\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Country', ylabel='Profit'>

# %%
data['Profit'].head(10)
# Out:
# 0     590
# 1     590
# 2    1366
# 3    1188
# 4     238
# 5     297
# 6     199
# 7     100
# 8    1096
# 9    1046
# Name: Profit, dtype: int64

# %%
data['Profit'].plot(kind='line', figsize=(16,6))
# Out:
# <AxesSubplot:>

# %%
data['Calculated_Date'] = data[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)

data['Calculated_Date'].head()
# Out:
# 0    2013-November-26
# 1    2015-November-26
# 2       2014-March-23
# 3       2016-March-23
# 4         2014-May-15
# Name: Calculated_Date, dtype: object

# %%
data['Calculated_Date'] = pd.to_datetime(data['Calculated_Date'])

data['Calculated_Date'].head()
# Out:
# 0   2013-11-26
# 1   2015-11-26
# 2   2014-03-23
# 3   2016-03-23
# 4   2014-05-15
# Name: Calculated_Date, dtype: datetime64[ns]

# %%
data['Calculated_Date'].value_counts().plot(kind='line', figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
data['Revenue'] += 50

# %%
data.loc[(data['Country'] == 'Canada') | (data['Country'] == 'France')].shape[0]
# Out:
# 25176

# %%
data['Country'].value_counts()
# Out:
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: Country, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
data['State'].value_counts()
# Out:
# California             22450
# British Columbia       14116
# England                13620
# Washington             11264
# New South Wales        10412
# Victoria                6016
# Oregon                  5286
# Queensland              5220
# Saarland                2770
# Nordrhein-Westfalen     2484
# Hessen                  2384
# Seine (Paris)           2328
# Hamburg                 1836
# Seine Saint Denis       1684
# Nord                    1670
# South Australia         1564
# Bayern                  1426
# Hauts de Seine          1084
# Essonne                  994
# Yveline                  954
# Tasmania                 724
# Seine et Marne           394
# Moselle                  386
# Loiret                   382
# Val d'Oise               264
# Garonne (Haute)          208
# Brandenburg              198
# Val de Marne             158
# Charente-Maritime        148
# Somme                    134
# Loir et Cher             120
# Pas de Calais             90
# ...

# %%
data.loc[data['Country'] == 'France', 'State'].value_counts()
# Out:
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: State, dtype: int64

# %%
data['Product_Category'].value_counts()
# Out:
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: Product_Category, dtype: int64

# %%
data['Product_Category'].value_counts().plot(kind='bar', figsize=(16,4))
# Out:
# <AxesSubplot:>

# %%
data.loc[data['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts()
# Out:
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: Sub_Category, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
data['Customer_Gender'].value_counts().head(1)
# Out:
# M    58312
# Name: Customer_Gender, dtype: int64

# %%
data.loc[(data['Customer_Gender'] == 'M') & (data['Revenue'] > 500)].value_counts().shape[0]
# Out:
# 21663

# %%
data.sort_values(['Revenue'], ascending=False).head(5)
# Out:
#               Date  Day      Month  Year  Customer_Age       Age_Group  \
# 112073  2015-07-24   24       July  2015            52  Adults (35-64)
# 112072  2013-07-24   24       July  2013            52  Adults (35-64)
# 71129   2011-07-08    8       July  2011            22     Youth (<25)
# 70307   2011-04-30   30      April  2011            44  Adults (35-64)
# 70601   2011-09-30   30  September  2011            19     Youth (<25)
#
#        Customer_Gender    Country             State Product_Category  \
# 112073               M  Australia        Queensland         Clothing
# 112072               M  Australia        Queensland         Clothing
# 71129                M     Canada           Alberta            Bikes
# 70307                M     Canada  British Columbia            Bikes
# 70601                F     Canada  British Columbia            Bikes
#
#        Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# ...

# %%
xyz = data['Revenue'] == data['Revenue'].max()

data.loc[xyz]
# Out:
#               Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073  2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category Sub_Category  \
# 112073               M  Australia  Queensland         Clothing        Vests
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 112073  Touring-1000 Yellow, 50              29       1482        2384
#
#         Profit   Cost  Revenue
# 112073   15096  42978    58074

# %%
cond = data['Revenue'] > 10_000

data.loc[cond, 'Order_Quantity'].mean()
# Out:
# 3.7218934911242605

# %%
data.loc[(data['Year'] == 2016) & (data['Month'] == "May")].shape[0]
# Out:
# 5015

# %%
cond = (data['Year'] == 2016) & (data['Month'] == 'May')

data.loc[cond].shape[0]
# Out:
# 5015

# %%
data.loc[(data['Year'] == 2016) & (data['Month'].isin(["May", "June", "july"]))].shape[0]
# Out:
# 10097

# %%
cond = data.loc[(data['Year'] == 2016, ['Profit', 'Month'])]

# %%
cond.boxplot(by='Month', figsize=(10,4))
# Out:
# <AxesSubplot:title={'center':'Profit'}, xlabel='[Month]'>

# %%
data.shape
# Out:
# (113036, 18)

# %%
data.loc[data['Country'] == 'United States', 'Unit_Price'] *= 1.072
